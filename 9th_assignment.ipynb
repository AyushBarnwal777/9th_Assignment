# %% [markdown]
# Q1. In Python, when creating a custom exception, it is recommended to inherit from the built-in Exception class or one of its subclasses. This is because the Exception class serves as the base class for all built-in exceptions, providing a consistent and standardized way to handle errors in the language.
#
# Here are a few reasons why you should use the Exception class as the base class for custom exceptions:
#
# Consistency with Built-in Exceptions:
#
# Inheriting from the Exception class ensures that your custom exception adheres to the same interface and behavior as the built-in exceptions.
# This consistency makes it easier for developers to understand and use your custom exception, as it follows the conventions established by the language.
# Compatibility with Exception Handling Mechanisms:
#
# Python's exception handling mechanisms, such as try, except, and finally blocks, are designed to work seamlessly with instances of the Exception class.
# Using the Exception class as the base class ensures that your custom exception can be caught and handled in a standardized way, just like built-in exceptions.
# Interoperability with Exception Hierarchies:
#
# Python's exception hierarchy is organized in a tree-like structure, with BaseException at the root and various specialized exceptions derived from it.
# Inheriting from Exception allows your custom exception to fit into this hierarchy, making it easier to organize and categorize different types of exceptions.
# Future Compatibility:
#
# Python may introduce new features or enhancements related to exception handling in future versions.
# By adhering to the established conventions and using the Exception class, your custom exception is more likely to remain compatible with future changes in the language.

# %%
#Q2.
import logging

logging.basicConfig(level=logging.DEBUG)

def print_exception_hierarchy(exception_class, indent=0):
    logger.debug("  " * indent + f"{exception_class.__name__}")
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 1)

if __name__ == "__main__":
    logger = logging.getLogger(__name__)
    logger.info("Python Exception Hierarchy:")

    try:
        # Triggering an exception to access the exception hierarchy
        raise Exception("Dummy Exception")
    except Exception as e:
        logger.debug(f"Base Exception: {e}")
        base_exception_class = type(e)
        print_exception_hierarchy(base_exception_class)
# Out:
# INFO:__main__:Python Exception Hierarchy:
# DEBUG:__main__:Base Exception: Dummy Exception
# DEBUG:__main__:Exception
# DEBUG:__main__:  ArithmeticError
# DEBUG:__main__:    FloatingPointError
# DEBUG:__main__:    OverflowError
# DEBUG:__main__:    ZeroDivisionError
# DEBUG:__main__:      DivisionByZero
# DEBUG:__main__:      DivisionUndefined
# DEBUG:__main__:    DecimalException
# DEBUG:__main__:      Clamped
# DEBUG:__main__:      Rounded
# DEBUG:__main__:        Underflow
# DEBUG:__main__:        Overflow
# DEBUG:__main__:      Inexact
# DEBUG:__main__:        Underflow
# DEBUG:__main__:        Overflow
# DEBUG:__main__:      Subnormal
# DEBUG:__main__:        Underflow
# DEBUG:__main__:      DivisionByZero
# DEBUG:__main__:      FloatOperation
# DEBUG:__main__:      InvalidOperation
# DEBUG:__main__:        ConversionSyntax
# DEBUG:__main__:        DivisionImpossible
# DEBUG:__main__:        DivisionUndefined
# DEBUG:__main__:        InvalidContext
# DEBUG:__main__:  AssertionError
# DEBUG:__main__:  AttributeError
# DEBUG:__main__:    FrozenInstanceError
# DEBUG:__main__:  BufferError
# DEBUG:__main__:  EOFError
# DEBUG:__main__:    IncompleteReadError
# DEBUG:__main__:  ImportError
# DEBUG:__main__:    ModuleNotFoundError
# DEBUG:__main__:      PackageNotFoundError
# DEBUG:__main__:    ZipImportError
# DEBUG:__main__:  LookupError
# DEBUG:__main__:    IndexError
# DEBUG:__main__:    KeyError
# DEBUG:__main__:      NoSuchKernel
# DEBUG:__main__:      UnknownBackend
# DEBUG:__main__:    CodecRegistryError
# DEBUG:__main__:  MemoryError
# DEBUG:__main__:  NameError
# DEBUG:__main__:    UnboundLocalError
# DEBUG:__main__:  OSError
# DEBUG:__main__:    BlockingIOError
# DEBUG:__main__:    ChildProcessError
# DEBUG:__main__:    ConnectionError
# DEBUG:__main__:      BrokenPipeError
# DEBUG:__main__:      ConnectionAbortedError
# DEBUG:__main__:      ConnectionRefusedError
# DEBUG:__main__:      ConnectionResetError
# DEBUG:__main__:        RemoteDisconnected
# DEBUG:__main__:    FileExistsError
# DEBUG:__main__:    FileNotFoundError
# DEBUG:__main__:    InterruptedError
# DEBUG:__main__:      InterruptedSystemCall
# DEBUG:__main__:    IsADirectoryError
# DEBUG:__main__:    NotADirectoryError
# DEBUG:__main__:    PermissionError
# DEBUG:__main__:    ProcessLookupError
# DEBUG:__main__:    TimeoutError
# DEBUG:__main__:    UnsupportedOperation
# DEBUG:__main__:    herror
# DEBUG:__main__:    gaierror
# DEBUG:__main__:    SSLError
# DEBUG:__main__:      SSLCertVerificationError
# DEBUG:__main__:      SSLZeroReturnError
# DEBUG:__main__:      SSLWantWriteError
# DEBUG:__main__:      SSLWantReadError
# DEBUG:__main__:      SSLSyscallError
# DEBUG:__main__:      SSLEOFError
# DEBUG:__main__:    Error
# DEBUG:__main__:      SameFileError
# DEBUG:__main__:    SpecialFileError
# DEBUG:__main__:    ExecError
# DEBUG:__main__:    ReadError
# DEBUG:__main__:    URLError
# DEBUG:__main__:      HTTPError
# DEBUG:__main__:      ContentTooShortError
# DEBUG:__main__:    BadGzipFile
# DEBUG:__main__:  ReferenceError
# DEBUG:__main__:  RuntimeError
# DEBUG:__main__:    NotImplementedError
# DEBUG:__main__:      ZMQVersionError
# DEBUG:__main__:      StdinNotImplementedError
# DEBUG:__main__:    RecursionError
# DEBUG:__main__:    _DeadlockError
# DEBUG:__main__:    BrokenBarrierError
# DEBUG:__main__:    BrokenExecutor
# DEBUG:__main__:      BrokenThreadPool
# DEBUG:__main__:    SendfileNotAvailableError
# DEBUG:__main__:    BrokenBarrierError
# DEBUG:__main__:    ExtractionError
# DEBUG:__main__:    VariableError
# DEBUG:__main__:  StopAsyncIteration
# DEBUG:__main__:  StopIteration
# DEBUG:__main__:  SyntaxError
# DEBUG:__main__:    IndentationError
# DEBUG:__main__:      TabError
# DEBUG:__main__:  SystemError
# DEBUG:__main__:    CodecRegistryError
# DEBUG:__main__:  TypeError
# DEBUG:__main__:    FloatOperation
# DEBUG:__main__:    MultipartConversionError
# DEBUG:__main__:  ValueError
# DEBUG:__main__:    UnicodeError
# DEBUG:__main__:      UnicodeDecodeError
# DEBUG:__main__:      UnicodeEncodeError
# DEBUG:__main__:      UnicodeTranslateError
# DEBUG:__main__:    UnsupportedOperation
# DEBUG:__main__:    JSONDecodeError
# DEBUG:__main__:    SSLCertVerificationError
# DEBUG:__main__:    Error
# DEBUG:__main__:    UnsupportedDigestmodError
# DEBUG:__main__:    IllegalMonthError
# DEBUG:__main__:    IllegalWeekdayError
# DEBUG:__main__:    ParserError
# DEBUG:__main__:    MessageDefect
# DEBUG:__main__:      NoBoundaryInMultipartDefect
# DEBUG:__main__:      StartBoundaryNotFoundDefect
# DEBUG:__main__:      CloseBoundaryNotFoundDefect
# DEBUG:__main__:      FirstHeaderLineIsContinuationDefect
# DEBUG:__main__:      MisplacedEnvelopeHeaderDefect
# DEBUG:__main__:      MissingHeaderBodySeparatorDefect
# DEBUG:__main__:      MultipartInvariantViolationDefect
# DEBUG:__main__:      InvalidMultipartContentTransferEncodingDefect
# DEBUG:__main__:      UndecodableBytesDefect
# DEBUG:__main__:      InvalidBase64PaddingDefect
# DEBUG:__main__:      InvalidBase64CharactersDefect
# DEBUG:__main__:      InvalidBase64LengthDefect
# DEBUG:__main__:      HeaderDefect
# DEBUG:__main__:        InvalidHeaderDefect
# DEBUG:__main__:        HeaderMissingRequiredValue
# DEBUG:__main__:        NonPrintableDefect
# DEBUG:__main__:        ObsoleteHeaderDefect
# DEBUG:__main__:        NonASCIILocalPartDefect
# DEBUG:__main__:        InvalidDateDefect
# DEBUG:__main__:    ClassNotFound
# DEBUG:__main__:    ClipboardEmpty
# DEBUG:__main__:    MacroToEdit
# DEBUG:__main__:    InvalidFileException
# DEBUG:__main__:    UnequalIterablesError
# DEBUG:__main__:    InvalidVersion
# DEBUG:__main__:    _InvalidELFFileHeader
# DEBUG:__main__:    InvalidWheelFilename
# DEBUG:__main__:    InvalidSdistFilename
# DEBUG:__main__:    InvalidSpecifier
# DEBUG:__main__:    InvalidMarker
# DEBUG:__main__:    UndefinedComparison
# DEBUG:__main__:    UndefinedEnvironmentName
# DEBUG:__main__:    InvalidRequirement
# DEBUG:__main__:      RequirementParseError
# DEBUG:__main__:    InvalidVersion
# DEBUG:__main__:  Warning
# DEBUG:__main__:    BytesWarning
# DEBUG:__main__:    DeprecationWarning
# DEBUG:__main__:      ProvisionalWarning
# DEBUG:__main__:    EncodingWarning
# DEBUG:__main__:    FutureWarning
# DEBUG:__main__:      ProvisionalCompleterWarning
# DEBUG:__main__:    ImportWarning
# DEBUG:__main__:    PendingDeprecationWarning
# DEBUG:__main__:    ResourceWarning
# DEBUG:__main__:    RuntimeWarning
# DEBUG:__main__:      ProactorSelectorThreadWarning
# DEBUG:__main__:      UnknownTimezoneWarning
# DEBUG:__main__:      PEP440Warning
# DEBUG:__main__:    SyntaxWarning
# DEBUG:__main__:    UnicodeWarning
# DEBUG:__main__:    UserWarning
# DEBUG:__main__:      GetPassWarning
# DEBUG:__main__:      FormatterWarning
# DEBUG:__main__:    DeprecatedTzFormatWarning
# DEBUG:__main__:    PkgResourcesDeprecationWarning
# DEBUG:__main__:  ExceptionGroup
# DEBUG:__main__:  _OptionError
# DEBUG:__main__:  _Error
# DEBUG:__main__:  error
# DEBUG:__main__:  Error
# DEBUG:__main__:  SubprocessError
# DEBUG:__main__:    CalledProcessError
# DEBUG:__main__:    TimeoutExpired
# DEBUG:__main__:  ZMQBaseError
# DEBUG:__main__:    ZMQError
# DEBUG:__main__:      ContextTerminated
# DEBUG:__main__:      Again
# DEBUG:__main__:      InterruptedSystemCall
# DEBUG:__main__:    ZMQBindError
# DEBUG:__main__:    NotDone
# DEBUG:__main__:  Error
# DEBUG:__main__:  error
# DEBUG:__main__:  PickleError
# DEBUG:__main__:    PicklingError
# DEBUG:__main__:    UnpicklingError
# DEBUG:__main__:  _Stop
# DEBUG:__main__:  TokenError
# DEBUG:__main__:  StopTokenizing
# DEBUG:__main__:  Error
# DEBUG:__main__:    CancelledError
# DEBUG:__main__:    InvalidStateError
# DEBUG:__main__:  _GiveupOnSendfile
# DEBUG:__main__:  Incomplete
# DEBUG:__main__:  ClassFoundException
# DEBUG:__main__:  EndOfBlock
# DEBUG:__main__:  InvalidStateError
# DEBUG:__main__:  LimitOverrunError
# DEBUG:__main__:  QueueEmpty
# DEBUG:__main__:  QueueFull
# DEBUG:__main__:  error
# DEBUG:__main__:  LZMAError
# DEBUG:__main__:  RegistryError
# DEBUG:__main__:  _GiveupOnFastCopy
# DEBUG:__main__:  TraitError
# DEBUG:__main__:  Empty
# DEBUG:__main__:  Full
# DEBUG:__main__:  ArgumentError
# DEBUG:__main__:  COMError
# DEBUG:__main__:  ReturnValueIgnoredError
# DEBUG:__main__:  ArgumentError
# DEBUG:__main__:  ArgumentTypeError
# DEBUG:__main__:  ConfigError
# DEBUG:__main__:    ConfigLoaderError
# DEBUG:__main__:      ArgumentError
# DEBUG:__main__:    ConfigFileNotFound
# DEBUG:__main__:  ConfigurableError
# DEBUG:__main__:    MultipleInstanceError
# DEBUG:__main__:  ApplicationError
# DEBUG:__main__:  InvalidPortNumber
# DEBUG:__main__:  NoIPAddresses
# DEBUG:__main__:  Error
# DEBUG:__main__:  BadZipFile
# DEBUG:__main__:  LargeZipFile
# DEBUG:__main__:  MessageError
# DEBUG:__main__:    MessageParseError
# DEBUG:__main__:      HeaderParseError
# DEBUG:__main__:      BoundaryError
# DEBUG:__main__:    MultipartConversionError
# DEBUG:__main__:    CharsetError
# DEBUG:__main__:  DuplicateKernelError
# DEBUG:__main__:  ErrorDuringImport
# DEBUG:__main__:  NotOneValueFound
# DEBUG:__main__:  KnownIssue
# DEBUG:__main__:  VerifierFailure
# DEBUG:__main__:  CannotEval
# DEBUG:__main__:  OptionError
# DEBUG:__main__:  BdbQuit
# DEBUG:__main__:  Restart
# DEBUG:__main__:  FindCmdError
# DEBUG:__main__:  HomeDirError
# DEBUG:__main__:  ProfileDirError
# DEBUG:__main__:  IPythonCoreError
# DEBUG:__main__:    TryNext
# DEBUG:__main__:    UsageError
# DEBUG:__main__:    StdinNotImplementedError
# DEBUG:__main__:  InputRejected
# DEBUG:__main__:  GetoptError
# DEBUG:__main__:  ErrorToken
# DEBUG:__main__:  PrefilterError
# DEBUG:__main__:  AliasError
# DEBUG:__main__:    InvalidAliasError
# DEBUG:__main__:  Error
# DEBUG:__main__:    InterfaceError
# DEBUG:__main__:    DatabaseError
# DEBUG:__main__:      InternalError
# DEBUG:__main__:      OperationalError
# DEBUG:__main__:      ProgrammingError
# DEBUG:__main__:      IntegrityError
# DEBUG:__main__:      DataError
# DEBUG:__main__:      NotSupportedError
# DEBUG:__main__:  Warning
# DEBUG:__main__:  SpaceInInput
# DEBUG:__main__:  DOMException
# DEBUG:__main__:    IndexSizeErr
# DEBUG:__main__:    DomstringSizeErr
# DEBUG:__main__:    HierarchyRequestErr
# DEBUG:__main__:    WrongDocumentErr
# DEBUG:__main__:    InvalidCharacterErr
# DEBUG:__main__:    NoDataAllowedErr
# DEBUG:__main__:    NoModificationAllowedErr
# DEBUG:__main__:    NotFoundErr
# DEBUG:__main__:    NotSupportedErr
# DEBUG:__main__:    InuseAttributeErr
# DEBUG:__main__:    InvalidStateErr
# DEBUG:__main__:    SyntaxErr
# DEBUG:__main__:    InvalidModificationErr
# DEBUG:__main__:    NamespaceErr
# DEBUG:__main__:    InvalidAccessErr
# DEBUG:__main__:    ValidationErr
# DEBUG:__main__:  ValidationError
# DEBUG:__main__:  EditReadOnlyBuffer
# DEBUG:__main__:  _Retry
# DEBUG:__main__:  InvalidLayoutError
# DEBUG:__main__:  HeightIsUnknownError
# DEBUG:__main__:  GuardRejection
# DEBUG:__main__:  ParserSyntaxError
# DEBUG:__main__:  InternalParseError
# DEBUG:__main__:  _PositionUpdatingFinished
# DEBUG:__main__:  SimpleGetItemNotFound
# DEBUG:__main__:  UncaughtAttributeError
# DEBUG:__main__:  HasNoContext
# DEBUG:__main__:  ParamIssue
# DEBUG:__main__:  _JediError
# DEBUG:__main__:    InternalError
# DEBUG:__main__:    WrongVersion
# DEBUG:__main__:    RefactoringError
# DEBUG:__main__:  OnErrorLeaf
# DEBUG:__main__:  InvalidPythonEnvironment
# DEBUG:__main__:  HTTPException
# DEBUG:__main__:    NotConnected
# DEBUG:__main__:    InvalidURL
# DEBUG:__main__:    UnknownProtocol
# DEBUG:__main__:    UnknownTransferEncoding
# DEBUG:__main__:    UnimplementedFileMode
# DEBUG:__main__:    IncompleteRead
# DEBUG:__main__:    ImproperConnectionState
# DEBUG:__main__:      CannotSendRequest
# DEBUG:__main__:      CannotSendHeader
# DEBUG:__main__:      ResponseNotReady
# DEBUG:__main__:    BadStatusLine
# DEBUG:__main__:      RemoteDisconnected
# DEBUG:__main__:    LineTooLong
# DEBUG:__main__:  InteractivelyDefined
# DEBUG:__main__:  KillEmbedded
# DEBUG:__main__:  Error
# DEBUG:__main__:    NoSuchProcess
# DEBUG:__main__:      ZombieProcess
# DEBUG:__main__:    AccessDenied
# DEBUG:__main__:    TimeoutExpired
# DEBUG:__main__:  Error
# DEBUG:__main__:  TimeoutExpired
# DEBUG:__main__:  TimeoutAbandoned
# DEBUG:__main__:  KeyReuseError
# DEBUG:__main__:  UnknownKeyError
# DEBUG:__main__:  LeakedCallbackError
# DEBUG:__main__:  BadYieldError
# DEBUG:__main__:  ReturnValueIgnoredError
# DEBUG:__main__:  Return
# DEBUG:__main__:  QueueEmpty
# DEBUG:__main__:  QueueFull
# DEBUG:__main__:  DebuggerInitializationError
# DEBUG:__main__:  ExpatError
# DEBUG:__main__:  Error
# DEBUG:__main__:    ProtocolError
# DEBUG:__main__:    ResponseError
# DEBUG:__main__:    Fault
# DEBUG:__main__:  error
# DEBUG:__main__:  com_error
# DEBUG:__main__:  internal_error
# DEBUG:__main__:  ParseBaseException
# DEBUG:__main__:    ParseException
# DEBUG:__main__:    ParseFatalException
# DEBUG:__main__:      ParseSyntaxException
# DEBUG:__main__:  RecursiveGrammarException
# DEBUG:__main__:  ResolutionError
# DEBUG:__main__:    VersionConflict
# DEBUG:__main__:      ContextualVersionConflict
# DEBUG:__main__:    DistributionNotFound
# DEBUG:__main__:    UnknownExtra
# DEBUG:__main__:  _Error
# DEBUG:__main__:  UnableToResolveVariableException
# DEBUG:__main__:  InvalidTypeInArgsException

# %% [markdown]
# Q3. The ArithmeticError class is a base class for exceptions that arise during arithmetic operations. It serves as the parent class for a variety of specific arithmetic exception classes in Python. Two common exceptions derived from ArithmeticError are ZeroDivisionError and OverflowError.
#
# ZeroDivisionError:
#
# Raised when division or modulo operation is performed with a divisor of zero.

# %%
try:
    result = 10 / 0
except ZeroDivisionError as e:
    print(f"Error: {e}")
# Out:
# Error: division by zero

# %% [markdown]
# OverflowError:
#
# Raised when an arithmetic operation exceeds the limits of the data type.

# %%
import sys

try:
    result = sys.maxsize + 1
except OverflowError as e:
    print(f"Error: {e}")

# %% [markdown]
# Q4. The LookupError class is the base class for exceptions that occur when a key or index is not found in a mapping or sequence, respectively. It provides a common base class for exceptions like KeyError and IndexError. The purpose of this class is to catch errors related to looking up keys or indices in a generic way.

# %%
import logging

logging.basicConfig(level=logging.DEBUG)

def example_key_error():
    my_dict = {'a': 1, 'b': 2, 'c': 3}
    try:
        value = my_dict['d']  # 'd' key does not exist
    except KeyError as e:
        logger.error(f"KeyError: {e}")

def example_index_error():
    my_list = [1, 2, 3, 4, 5]
    try:
        value = my_list[10]  # Index 10 is out of range
    except IndexError as e:
        logger.error(f"IndexError: {e}")

if __name__ == "__main__":
    logger = logging.getLogger(__name__)
    logger.info("Examples of KeyError and IndexError:")

    example_key_error()
    example_index_error()
# Out:
# INFO:__main__:Examples of KeyError and IndexError:
# ERROR:__main__:KeyError: 'd'
# ERROR:__main__:IndexError: list index out of range

# %% [markdown]
# Q5. ImportError is a base class for exceptions that occur when an import statement cannot locate the specified module. It can be raised in various situations, such as when a module is not found, cannot be imported, or contains errors that prevent its proper functioning.
#
# The ModuleNotFoundError is a specific subclass of ImportError introduced in Python 3.6. It is raised when the import statement cannot find the specified module or when trying to import a module that doesn't exist.

# %% [markdown]
# Q6. Exception handling is a crucial aspect of writing robust and maintainable Python code. Here are some best practices for effective exception handling in Python:
#
# Use Specific Exceptions:
#
# Catch specific exceptions rather than using a generic except block. This allows you to handle different types of errors in specific ways.
#
# Keep try Blocks Small:
#
# Limit the amount of code within a try block to the minimum necessary to identify and handle the exception. This makes it easier to pinpoint the cause of an exception.
#
# Avoid Using Bare except:
#
# Avoid using a bare except block as it catches all exceptions, making it difficult to identify and handle specific issues. Be explicit about the exceptions you intend to catch.
#
# Use finally for Cleanup:
#
# Use the finally block for cleanup code that should be executed whether an exception occurs or not, such as closing files or releasing resources.
#
# Handle Exceptions Locally:
#
# Handle exceptions at the most appropriate level in your code rather than letting them propagate too far. This enhances code readability and allows for more targeted error handling.
# Log Exceptions:
#
# Use logging to capture details about exceptions. Logging provides valuable information for debugging and understanding the context in which an exception occurred.
#
# Raise Exceptions Sparingly:
#
# Raise exceptions only in exceptional cases. Avoid using exceptions for flow control. Use return values or other mechanisms for routine error handling.
# Create Custom Exceptions:
#
# Create custom exception classes when necessary to handle application-specific errors. This improves code readability and allows you to differentiate between different types of errors.
#
# Use with Statement for Resources:
#
# When dealing with external resources like files or network connections, use the with statement to ensure proper resource cleanup. Many objects support the context management protocol, which automatically handles resource allocation and deallocation.
#
# Test Exception Handling:
#
# Include unit tests for your exception handling code to ensure that it behaves as expected in different error scenarios.
